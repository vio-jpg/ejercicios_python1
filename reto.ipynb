# %% [markdown]
# <a href="https://colab.research.google.com/github/vio-jpg/ejercicios_python1/blob/main/reto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  Mini Reto 3:
# crear 3 variables: nombre, edad y si les gusta la pizza(True/False)
# Imprimir mensaje como: "Hola, soy Ana, tengo 25 años y ¿me gusta la pizza? True"

# %%
nombre = input("¿Cual es tu nombre? ")
edad = input("¿Cual es tu edad? ")
pizza = input("¿Te gusta la pizza? ")

print("Hola, soy " + nombre + ", tengo " + edad + " años y ¿me gusta la pizza? " + pizza)
# Out:
# ¿Cual es tu nombre? ana
# ¿Cual es tu edad? 25
# ¿Te gusta la pizza? si
# Hola, soy ana, tengo 25 años y ¿me gusta la pizza? si

# %% [markdown]
# <a href="https://colab.research.google.com/github/vio-jpg/ejercicios_python1/blob/main/RetoHora.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Dependiendo de la hora, tu app te dirá si es
# la hora de:
# - Desayuno 8:00 a 10:00
# - Comida 14:00 a 15:00
# - Merienda 17:00 a 19:00
# - Cena 20:00 a 22:00
# Por cada tiempo de comida te ofrece 2 o 3
# platos a elegir

# %%
from datetime import datetime
from zoneinfo import ZoneInfo
ahora = datetime.now(ZoneInfo("Europe/Madrid"))
hora = ahora.hour + ahora.minute / 60
entrada = input("¿Qué hora es? (Enter si no lo sabe, el sistema detectará la hora que es): ")
if entrada != "":
    if ":" in entrada:
        h, m = entrada.split(":")
        hora_cliente = int(h) + int(m) / 60
    else:
        hora_cliente = int(entrada)
if 8 <= hora <= 10 or (entrada != "" and 8 <= hora_cliente <= 10):
    print("A desayunar")
    print("Elige menú: a o b")
    print("a. Café con leche y tostadas con tomate")
    print("b. Colacao y yogur con fruta")
    eleccion= input("¿Que desea desayunar? ")
    if eleccion=="a":
      print("Ha seleccionado el menu a:Café con leche y tostadas con tomate, que lo disfrute.")
    elif eleccion=="b":
      print("Ha seleccionado el menu b:Colacao y yogur con fruta, que lo disfrute.")
    else:
      print("Seleccion no valida, introduzca a o b")
elif 14 <= hora <= 15 or (entrada != "" and 14 <= hora_cliente <= 15):
    print("A comer")
    print("Elige menú: a o b")
    print("a. Pechugas de pollo y arroz")
    print("b. Hamburguesa vegetariana")
    eleccion= input("¿Que desea comer? ")
    if eleccion=="a":
      print("Ha seleccionado el menu a:Pechugas de pollo y arroz, que lo disfrute.")
    elif eleccion=="b":
      print("Ha seleccionado el menu b:Hamburguesa vegetariana, que lo disfrute.")
    else:
      print("Seleccion no valida, introduzca a o b")
elif 17<=hora<=19 or (entrada != "" and 17 <= hora_cliente <= 19):
  print("A merendar")
  print("Elige menú: a o b")
  print("a. Manzana")
  print("b. Sandwich de nutella")
  eleccion= input("¿Que desea merendar? ")
  if eleccion=="a":
    print("Ha seleccionado el menu a:Manzana, que lo disfrute.")
  elif eleccion=="b":
    print("Ha seleccionado el menu b:Sandwich de nutella, que lo disfrute.")
  else:
    print("Seleccion no valida, introduzca a o b")
elif 20<=hora<=22 or (entrada != "" and 20 <= hora_cliente <= 22):
  print("A cenar")
  print("Elige menú: a o b")
  print("a. Sopa con fideos")
  print("b. Crema de calabacin")
  eleccion= input("¿Que desea cenar? ")
  if eleccion=="a":
      print("Ha seleccionado el menu a:sopa con fideos, que lo disfrute.")
  elif eleccion=="b":
      print("Ha seleccionado el menu b:crema de calabacin, que lo disfrute.")
  else:
    print("Seleccion no valida, introduzca a o b")
else:
  print("No es hora de ninguna de las comidas. Se desayuna de 8.00 a 11:00, la comida sera entre la 13:00 y las 15:00, y la cena es de 20:00 a 22:00.")
# Out:
# ¿Qué hora es? (Enter si no lo sabe, el sistema detectará la hora que es): 15
# A comer
# Elige menú: a o b
# a. Pechugas de pollo y arroz
# b. Hamburguesa vegetariana
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_6870/910045158.py in <cell line: 0>()
#      27     print("a. Pechugas de pollo y arroz")
#      28     print("b. Hamburguesa vegetariana")
# ---> 29     eleccion= input("¿Que desea comer? ")
#      30     if eleccion=="a":
#      31       print("Ha seleccionado el menu a:Pechugas de pollo y arroz, que lo disfrute.")
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
# ...

# %% [markdown]
# <a href="https://colab.research.google.com/github/vio-jpg/ejercicios_python1/blob/main/Inventario.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# creamos un pequeño programa que descuente el inventario de una hamburgueseria

# %%
inventario = 100
print(f"El inventario contiene {inventario} hamburguesas")
while inventario > 0:
  if inventario <= 10:
    print("El inventario esta casi vacio: CUIDADO!")
  num_hamburguesas = int(input("Cuantas hamburguesas quiere el cliente? "))
  if num_hamburguesas > inventario:
    print("no hay suficiente hamburguesas. Solo hay", inventario, "hamburguesas")
  else:
    inventario -= num_hamburguesas
    print(f"El cliente ha pedido {num_hamburguesas} hamburguesas. El inventario ahora tiene {inventario} hamburguesas")
# Out:
# El inventario contiene 100 hamburguesas
# Cuantas hamburguesas quiere el cliente? 56
# El cliente ha pedido 56 hamburguesas. El inventario ahora tiene 44 hamburguesas
# Cuantas hamburguesas quiere el cliente? 44
# El cliente ha pedido 44 hamburguesas. El inventario ahora tiene 0 hamburguesas
